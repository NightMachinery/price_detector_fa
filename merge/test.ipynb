# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Bootstrap

# %%
cache = dict()

# %%
from price_detector_fa.samples import *
from price_detector_fa.utils import *
from price_detector_fa.extractors import *
from price_detector_fa.preprocessing import *
from price_detector_fa.hardcoded import *

# %% [markdown]
# # Tests

# %% [markdown]
# ## `preprocess`

# %%
print([i for i in zip(preprocess(sample_5)[0], preprocess(sample_5)[1])])
print ("\'"+sample_5[14:22]+"\'")
# Out:
# ic| text: ('ولی ما هرکیلو ماکارونی را فقط ۰.۳۵ $ فروخته ایم، در حالی که قیمت جهانی '
#            'هرکیلو گندم بیش ۰.۴$ است.')
# ['ولی', 'ما', 'یک', 'کیلو', 'ماکارونی', 'را', 'فقط', '۰.۳۵', 'دلار', 'فروخته', 'ایم', '،', 'در', 'حالی', 'که', 'قیمت', 'جهانی', 'یک', 'کیلو', 'گندم', 'بیش', '۰.۴', 'دلار', 'است', '.']
# ic| text: ('ولی ما هر کیلو ماکارونی را فقط ۰.۳۵ $ فروخته ایم، در حالی که قیمت هر کیلو '
#            'گندم بیش ۰.۴$ است.')
# ic| text: ('ولی ما هرکیلو ماکارونی را فقط ۰.۳۵ $ فروخته ایم، در حالی که قیمت جهانی '
#            'هرکیلو گندم بیش ۰.۴$ است.')
# ['ولی', 'ما', 'یک', 'کیلو', 'ماکارونی', 'را', 'فقط', '۰.۳۵', 'دلار', 'فروخته', 'ایم', '،', 'در', 'حالی', 'که', 'قیمت', 'جهانی', 'یک', 'کیلو', 'گندم', 'بیش', '۰.۴', 'دلار', 'است', '.']
# ic| text: ('ولی ما هر کیلو ماکارونی را فقط ۰.۳۵ $ فروخته ایم، در حالی که قیمت هر کیلو '
#            'گندم بیش ۰.۴$ است.')
# [('ولی', (0, 3)), ('ما', (4, 6)), ('یک', (7, 9)), ('کیلو', (9, 13)), ('ماکارونی', (14, 22)), ('را', (23, 25)), ('فقط', (26, 29)), ('۰.۳۵', (30, 34)), ('دلار', (35, 36)), ('فروخته', (37, 43)), ('ایم', (44, 47)), ('،', (47, 48)), ('در', (49, 51)), ('حالی', (52, 56)), ('که', (57, 59)), ('قیمت', (60, 64)), ('یک', (71, 73)), ('کیلو', (73, 77)), ('گندم', (78, 82)), ('۰.۴', (87, 90)), ('دلار', (90, 91)), ('است', (92, 95)), ('.', (95, 96))]
# 'ماکارونی'

# %% [markdown]
# ## subject_extract

# %%
subject_extract(parser.parse(preprocess(sample_13)[0]))
# Out:
# ic| text: 'هندوانه هرکیلو سه هزار تومان به فروش میرسد.'
# ['هندوانه', 'یک', 'کیلو', 'سه', 'هزار', 'تومان', 'به', 'فروش', 'میرسد', '.']
# ic| text: 'هندوانه هر کیلو سه هزار تومان به فروش میرسد.'
# [{'nodes': [{'address': 1,
#     'word': 'هندوانه',
#     'lemma': 'هندوانه',
#     'ctag': 'N',
#     'tag': 'N',
#     'feats': '_',
#     'head': 9,
#     'deps': defaultdict(list, {'MOZ': [3]}),
#     'rel': 'SBJ'},
#    {'address': 2,
#     'word': 'یک',
#     'lemma': 'یک',
#     'ctag': 'NUM',
#     'tag': 'NUM',
#     'feats': '_',
#     'head': 3,
#     'deps': defaultdict(list, {}),
#     'rel': 'NPREMOD'},
#    {'address': 3,
#     'word': 'کیلو',
#     'lemma': 'کیلو',
#     'ctag': 'N',
#     'tag': 'N',
#     'feats': '_',
#     'head': 1,
#     'deps': defaultdict(list, {'NPREMOD': [2]}),
#     'rel': 'MOZ'}]}]

# %% [markdown]
# ## All Together

# %%
from price_detector_fa.samples import *

for s in (
    # sample_1,
    # sample_2,
    # sample_2_1,
    # sample_2_2,
    # sample_2_3,
    # sample_2_4,
    # sample_2_5,
    # sample_2_6,
    # sample_2_7,
    # sample_2_8,
    # sample_2_9,
    # sample_2_9_2,
    # sample_3,
    # sample_4,
    # sample_5,
    # sample_6,
    # sample_7,
    # sample_8,
    # sample_8_2,
    # sample_8_3,
    # sample_13,
    # sample_14,
    sample_15,
    # *samples_evil,
    # *samples,
):
    print(s)
    if True or s not in cache:
        #: @todo6/Hoseini fix the return types
        s_tokens, s_indices = preprocess(s)

        s_parsed = parser.parse(s_tokens)
        # print (s_parsed)
        s_node_spans = find_spans(s_parsed, s_indices)
        print(s_node_spans)
        s_tagged = tagger.tag(s_tokens)
        s_chunks = tree2brackets(chunker.parse(s_tagged))
        cache[s] = dict(
            s_tokens=s_tokens,
            s_parsed=s_parsed,
            s_tagged=s_tagged,
            s_chunks=s_chunks,
        )
    s_cached = cache[s]
    s_tokens = s_cached["s_tokens"]
    s_parsed = s_cached["s_parsed"]
    s_tagged = s_cached["s_tagged"]
    s_chunks = s_cached["s_chunks"]
    ic(s_chunks)

    print (s_tokens[10])
    display(s_parsed)
    all_extract(s_parsed)
    print()
# Out:
# مدیریت امور بین‌الملل شرکت ملی نفت ایران قیمت نفت خام سبک، نفت خام سنگین و فروزان را برای فروش در ماه دسامبر به ترتیب ۵ دلار و ۳۵ سنت، یک دلار و ۸۵ سنت، یک دلار و ۹۵ سنت بالاتر از میانگین قیمت نفت عمان/ دوبی قیمت‌گذاری کرده است.
# ic| text: ('مدیریت امور بین\u200cالملل شرکت ملی نفت ایران قیمت نفت خام سبک، نفت خام '
#            'سنگین و فروزان را برای فروش در ماه دسامبر به ترتیب ۵ دلار و ۳۵ سنت، یک دلار '
#            'و ۸۵ سنت، یک دلار و ۹۵ سنت بالاتر از میانگین قیمت نفت عمان/ دوبی '
#            'قیمت\u200cگذاری کرده است.')
# ['مدیریت', 'امور', 'بین', '\u200c', 'الملل', 'شرکت', 'ملی', 'نفت', 'ایران', 'قیمت', 'نفت', 'خام', 'سبک', '،', 'نفت', 'خام', 'سنگین', 'و', 'فروزان', 'را', 'برای', 'فروش', 'در', 'ماه', 'دسامبر', 'به', 'ترتیب', '۵', 'دلار', 'و', '۳۵', 'سنت', '،', 'یک', 'دلار', 'و', '۸۵', 'سنت', '،', 'یک', 'دلار', 'و', '۹۵', 'سنت', 'بالاتر', 'از', 'میانگین', 'قیمت', 'نفت', 'عمان', '/', 'دوبی', 'قیمت', '\u200c', 'گذاری', 'کرده', 'است', '.']
# ic| text: ('مدیریت امور بین\u200cالملل شرکت ملی نفت ایران قیمت نفت خام سبک، نفت خام '
#            'سنگین و فروزان را برای فروش در ماه دسامبر به ترتیب ۵ دلار و ۳۵ سنت، یک دلار '
#            'و ۸۵ سنت، یک دلار و ۹۵ سنت بالاتر از میانگین قیمت نفت عمان/ دوبی '
#            'قیمت\u200cگذاری کرده است.')
# {0: (227, 228), 1: (0, 6), 57: (224, 227), 2: (7, 11), 3: (12, 15), 56: (219, 223), 4: (15, 16), 5: (16, 21), 6: (22, 26), 7: (27, 30), 8: (31, 34), 9: (35, 40), 10: (41, 45), 20: (82, 84), 11: (46, 49), 12: (50, 53), 13: (54, 57), 14: (57, 58), 15: (59, 62), 16: (63, 66), 17: (67, 72), 18: (73, 74), 19: (75, 81), 21: (85, 89), 22: (90, 94), 23: (95, 97), 24: (98, 101), 25: (102, 108), 26: (109, 111), 27: (112, 117), 28: (118, 119), 29: (120, 124), 30: (125, 126), 31: (127, 129), 32: (130, 133), 33: (133, 134), 34: (135, 137), 35: (138, 142), 36: (143, 144), 37: (145, 147), 38: (148, 151), 39: (151, 152), 40: (153, 155), 41: (156, 160), 42: (161, 162), 43: (163, 165), 44: (166, 169), 45: (170, 176), 46: (177, 179), 47: (180, 187), 48: (188, 192), 49: (193, 196), 50: (197, 201), 51: (201, 202), 52: (203, 207), 53: (208, 212), 54: (212, 213), 55: (213, 218), 58: (227, 228)}
# ic| s_chunks: ('[مدیریت امور NP] [بین PP] [\u200c الملل شرکت ملی نفت ایران NP] [قیمت نفت خام '
#                'سبک NP] ، [نفت خام سنگین و فروزان NP] [را POSTP] [برای PP] [فروش NP] [در PP] '
#                '[ماه دسامبر NP] [به PP] [ترتیب NP] [۵ دلار و ۳۵ سنت NP] ، [یک دلار و ۸۵ سنت '
#                'NP] ، [یک دلار و ۹۵ سنت بالاتر NP] [از PP] [میانگین قیمت نفت عمان / دوبی '
#                'قیمت NP] [\u200c ADVP] [گذاری کرده VP] [است VP] .')
# نفت
# <DependencyGraph with 59 nodes>
# ic| extracted_show(price_extracted): ['مقدار:  ۵ دلار و ۳۵ سنت',
#                                       'مقدار:  ۳۵ سنت',
#                                       'مقدار:  یک دلار و ۸۵ سنت',
#                                       'مقدار:  ۸۵ سنت',
#                                       'مقدار:  یک دلار و ۹۵ سنت',
#                                       'مقدار:  ۹۵ سنت']
# ic| extracted_show(unit_extracted): []
# ic| end_index: 19
# ic| end_index: 58
# ic| end_index: 58
# ic| extracted_show(product_name_extracted): ['مقدار:  نفت خام سبک ، نفت خام سنگین و فروزان',
#                                              'مقدار:  نفت عمان / دوبی قیمت \u200c گذاری کرده است .',
#                                              'مقدار:  \u200c گذاری کرده است .']
